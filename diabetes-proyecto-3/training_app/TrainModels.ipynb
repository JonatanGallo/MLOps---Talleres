# %%
from etl import get_batch_amount,load_raw_data, clear_data

# %%
# print(get_batch_amount(15000))

# %%
raw_data = load_raw_data(1, 15000)
print(raw_data.head())
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
clean_data, column_names = clear_data(raw_data, True)
print(column_names, clean_data)
# Out:
# readmitted unique [0 1]
# readmitted unique readmitted
# 0    12450
# 1     1618
# Name: count, dtype: int64
# numerics ['num_lab_procedures', 'num_medications', 'number_inpatient', 'num_procedures', 'number_diagnoses', 'time_in_hospital', 'number_outpatient', 'readmitted', 'number_emergency']
# numerics after removing readmitted ['num_lab_procedures', 'num_medications', 'number_inpatient', 'num_procedures', 'number_diagnoses', 'time_in_hospital', 'number_outpatient', 'number_emergency']
# numerics ['num_lab_procedures', 'num_medications', 'number_inpatient', 'num_procedures', 'number_diagnoses', 'time_in_hospital', 'number_outpatient', 'readmitted', 'number_emergency']
# numerics after removing readmitted ['num_lab_procedures', 'num_medications', 'number_inpatient', 'num_procedures', 'number_diagnoses', 'time_in_hospital', 'number_outpatient', 'number_emergency']
# df_encoded readmitted 1    0
# 3    0
# 4    0
# 5    0
# 6    0
# Name: readmitted, dtype: int64
# ...
