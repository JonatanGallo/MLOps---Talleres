# %%
from dataController import store_raw_data, save_all_clean_data
from etl import get_batch_amount

# %%
amount_per_batch = 15000
batch_number = get_batch_amount(amount_per_batch)
print(batch_number)

# %%
for i in range(batch_number):
  print("Iteration: ", i)
  store_raw_data(i + 1, amount_per_batch)

# %%
save_all_clean_data()
print("clean data saved")
# Out:
# 🔒 MySQL connection closed
# readmitted unique [0 1]
# readmitted unique readmitted
# 0    60915
# 1     7745
# Name: count, dtype: int64
# numerics ['readmitted', 'diabetesMed']
# numerics after removing readmitted ['diabetesMed']
# numerics ['readmitted', 'diabetesMed']
# numerics after removing readmitted ['diabetesMed']
# df_encoded readmitted 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: readmitted, dtype: int64
# Balancing dataset... 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: readmitted, dtype: int64
# create_table_with_types ddl
#     CREATE TABLE IF NOT EXISTS `clean_data_train` (
#       `id` BIGINT UNSIGNED NOT NULL AUTO_INCREMENT,
#       `age` VARCHAR(2) NOT NULL DEFAULT '',
#   `time_in_hospital` VARCHAR(2) NOT NULL DEFAULT '',
#   `num_procedures` VARCHAR(1) NOT NULL DEFAULT '',
#   `num_medications` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_outpatient` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_emergency` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_inpatient` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_diagnoses` VARCHAR(2) NOT NULL DEFAULT '',
#   `gender_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_10` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_11` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_12` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_13` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_14` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_15` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_16` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_17` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_18` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_19` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_20` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_22` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_23` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_24` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_25` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_27` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_28` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_9` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_10` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_11` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_13` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_17` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_20` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_22` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_25` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_9` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `max_glu_serum_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `max_glu_serum_` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `A1Cresult_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `A1Cresult_` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Asian` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Caucasian` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Hispanic` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Other` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `chlorpropamide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `chlorpropamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `chlorpropamide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acetohexamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolbutamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `miglitol_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `miglitol_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `miglitol_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `troglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolazamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolazamide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `diabetesMed_0.5642587368229394` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `readmitted` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#       `row_hash` BINARY(32)
#         GENERATED ALWAYS AS (UNHEX(SHA2(CONCAT_WS('|',COALESCE(`age`,''), COALESCE(`time_in_hospital`,''), COALESCE(`num_procedures`,''), COALESCE(`num_medications`,''), COALESCE(`number_outpatient`,''), COALESCE(`number_emergency`,''), COALESCE(`number_inpatient`,''), COALESCE(`number_diagnoses`,''), COALESCE(`gender_1`,''), COALESCE(`admission_type_id_2`,''), COALESCE(`admission_type_id_3`,''), COALESCE(`admission_type_id_4`,''), COALESCE(`admission_type_id_5`,''), COALESCE(`admission_type_id_6`,''), COALESCE(`admission_type_id_7`,''), COALESCE(`admission_type_id_8`,''), COALESCE(`discharge_disposition_id_10`,''), COALESCE(`discharge_disposition_id_11`,''), COALESCE(`discharge_disposition_id_12`,''), COALESCE(`discharge_disposition_id_13`,''), COALESCE(`discharge_disposition_id_14`,''), COALESCE(`discharge_disposition_id_15`,''), COALESCE(`discharge_disposition_id_16`,''), COALESCE(`discharge_disposition_id_17`,''), COALESCE(`discharge_disposition_id_18`,''), COALESCE(`discharge_disposition_id_19`,''), COALESCE(`discharge_disposition_id_2`,''), COALESCE(`discharge_disposition_id_20`,''), COALESCE(`discharge_disposition_id_22`,''), COALESCE(`discharge_disposition_id_23`,''), COALESCE(`discharge_disposition_id_24`,''), COALESCE(`discharge_disposition_id_25`,''), COALESCE(`discharge_disposition_id_27`,''), COALESCE(`discharge_disposition_id_28`,''), COALESCE(`discharge_disposition_id_3`,''), COALESCE(`discharge_disposition_id_4`,''), COALESCE(`discharge_disposition_id_5`,''), COALESCE(`discharge_disposition_id_6`,''), COALESCE(`discharge_disposition_id_7`,''), COALESCE(`discharge_disposition_id_8`,''), COALESCE(`discharge_disposition_id_9`,''), COALESCE(`admission_source_id_10`,''), COALESCE(`admission_source_id_11`,''), COALESCE(`admission_source_id_13`,''), COALESCE(`admission_source_id_17`,''), COALESCE(`admission_source_id_2`,''), COALESCE(`admission_source_id_20`,''), COALESCE(`admission_source_id_22`,''), COALESCE(`admission_source_id_25`,''), COALESCE(`admission_source_id_3`,''), COALESCE(`admission_source_id_4`,''), COALESCE(`admission_source_id_5`,''), COALESCE(`admission_source_id_6`,''), COALESCE(`admission_source_id_7`,''), COALESCE(`admission_source_id_8`,''), COALESCE(`admission_source_id_9`,''), COALESCE(`max_glu_serum_1`,''), COALESCE(`max_glu_serum_`,''), COALESCE(`A1Cresult_1`,''), COALESCE(`A1Cresult_`,''), COALESCE(`race_Asian`,''), COALESCE(`race_Caucasian`,''), COALESCE(`race_Hispanic`,''), COALESCE(`race_Other`,''), COALESCE(`metformin_No`,''), COALESCE(`metformin_Steady`,''), COALESCE(`metformin_Up`,''), COALESCE(`repaglinide_No`,''), COALESCE(`repaglinide_Steady`,''), COALESCE(`repaglinide_Up`,''), COALESCE(`nateglinide_No`,''), COALESCE(`nateglinide_Steady`,''), COALESCE(`nateglinide_Up`,''), COALESCE(`chlorpropamide_No`,''), COALESCE(`chlorpropamide_Steady`,''), COALESCE(`chlorpropamide_Up`,''), COALESCE(`glimepiride_No`,''), COALESCE(`glimepiride_Steady`,''), COALESCE(`glimepiride_Up`,''), COALESCE(`acetohexamide_Steady`,''), COALESCE(`glipizide_No`,''), COALESCE(`glipizide_Steady`,''), COALESCE(`glipizide_Up`,''), COALESCE(`glyburide_No`,''), COALESCE(`glyburide_Steady`,''), COALESCE(`glyburide_Up`,''), COALESCE(`tolbutamide_Steady`,''), COALESCE(`pioglitazone_No`,''), COALESCE(`pioglitazone_Steady`,''), COALESCE(`pioglitazone_Up`,''), COALESCE(`rosiglitazone_No`,''), COALESCE(`rosiglitazone_Steady`,''), COALESCE(`rosiglitazone_Up`,''), COALESCE(`acarbose_No`,''), COALESCE(`acarbose_Steady`,''), COALESCE(`acarbose_Up`,''), COALESCE(`miglitol_No`,''), COALESCE(`miglitol_Steady`,''), COALESCE(`miglitol_Up`,''), COALESCE(`troglitazone_Steady`,''), COALESCE(`tolazamide_Steady`,''), COALESCE(`tolazamide_Up`,''), COALESCE(`insulin_No`,''), COALESCE(`insulin_Steady`,''), COALESCE(`insulin_Up`,''), COALESCE(`diabetesMed_0.5642587368229394`,''), COALESCE(`readmitted`,'')), 256))) STORED,
#       UNIQUE KEY `uniq_row_hash` (`row_hash`),
#       PRIMARY KEY (`id`)
#     ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 ROW_FORMAT=DYNAMIC;
#
# 🔒 MySQL connection closed
# After create clean data  train
# Inserting in index 0
# ✅ Inserted 4995 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 5000
# ✅ Inserted 4994 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 10000
# ✅ Inserted 4995 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 15000
# ✅ Inserted 4992 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 20000
# ✅ Inserted 4986 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 25000
# ✅ Inserted 4975 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 30000
# ✅ Inserted 4979 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 35000
# ✅ Inserted 4953 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 40000
# ✅ Inserted 4944 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 45000
# ✅ Inserted 3024 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 50000
# ✅ Inserted 377 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 55000
# ✅ Inserted 330 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 60000
# ✅ Inserted 310 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 65000
# ✅ Inserted 259 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 70000
# ✅ Inserted 241 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 75000
# ✅ Inserted 214 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 80000
# ✅ Inserted 210 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 85000
# ✅ Inserted 176 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 90000
# ✅ Inserted 175 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 95000
# ✅ Inserted 160 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 100000
# ✅ Inserted 132 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 105000
# ✅ Inserted 136 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 110000
# ✅ Inserted 110 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 115000
# ✅ Inserted 104 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 120000
# ✅ Inserted 99 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 125000
# ✅ Inserted 77 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 130000
# ✅ Inserted 84 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 135000
# ✅ Inserted 67 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 140000
# ✅ Inserted 63 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 145000
# ✅ Inserted 58 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 150000
# ✅ Inserted 54 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 155000
# ✅ Inserted 43 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 160000
# ✅ Inserted 45 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 165000
# ✅ Inserted 44 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 170000
# ✅ Inserted 37 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 175000
# ✅ Inserted 25 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 180000
# ✅ Inserted 40 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 185000
# ✅ Inserted 35 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 190000
# ✅ Inserted 24 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 195000
# ✅ Inserted 23 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 200000
# ✅ Inserted 24 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 205000
# ✅ Inserted 18 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 210000
# ✅ Inserted 13 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 215000
# ✅ Inserted 20 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 220000
# ✅ Inserted 16 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 225000
# ✅ Inserted 11 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 230000
# ✅ Inserted 12 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 235000
# ✅ Inserted 7 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 240000
# ✅ Inserted 12 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 245000
# ✅ Inserted 3 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 250000
# ✅ Inserted 10 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 255000
# ✅ Inserted 10 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 260000
# ✅ Inserted 4 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 265000
# ✅ Inserted 4 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 270000
# ✅ Inserted 6 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 275000
# ✅ Inserted 4 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 280000
# ✅ Inserted 4 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 285000
# ✅ Inserted 6 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 290000
# ✅ Inserted 5 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 295000
# ✅ Inserted 6 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 300000
# ✅ Inserted 2 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 305000
# ✅ Inserted 3 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 310000
# ✅ Inserted 3 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 315000
# ✅ Inserted 5 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 320000
# ✅ Inserted 2 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 325000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 330000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 335000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 340000
# ✅ Inserted 2 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 345000
# ✅ Inserted 3 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 350000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 355000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 360000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 365000
# ✅ Inserted 3 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 370000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 375000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 380000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 385000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 390000
# ✅ Inserted 3 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 395000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 400000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 405000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 410000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 415000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 420000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 425000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 430000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 435000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 440000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 445000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 450000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 455000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 460000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 465000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 470000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 475000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 480000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 485000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 490000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 495000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 500000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 505000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 510000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 515000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 520000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 525000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 530000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 535000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 540000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 545000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 550000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 555000
# ✅ Inserted 1 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 560000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 565000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 570000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 575000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 580000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 585000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 590000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 595000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 600000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 605000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 610000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 615000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 620000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 625000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 630000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 635000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 640000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# Inserting in index 645000
# ✅ Inserted 0 rows into clean_data_train
# 🔒 MySQL connection closed
# 🔒 MySQL connection closed
# readmitted unique [0 1]
# readmitted unique readmitted
# 0    17410
# 1     2211
# Name: count, dtype: int64
# numerics ['readmitted', 'diabetesMed']
# numerics after removing readmitted ['diabetesMed']
# numerics ['readmitted', 'diabetesMed']
# numerics after removing readmitted ['diabetesMed']
# df_encoded readmitted 0    0
# 2    0
# 3    0
# 4    1
# 5    0
# Name: readmitted, dtype: int64
# create_table_with_types ddl
#     CREATE TABLE IF NOT EXISTS `clean_data_validate` (
#       `id` BIGINT UNSIGNED NOT NULL AUTO_INCREMENT,
#       `encounter_id` VARCHAR(9) NOT NULL DEFAULT '',
#   `patient_nbr` VARCHAR(9) NOT NULL DEFAULT '',
#   `age` VARCHAR(2) NOT NULL DEFAULT '',
#   `time_in_hospital` VARCHAR(2) NOT NULL DEFAULT '',
#   `num_lab_procedures` VARCHAR(3) NOT NULL DEFAULT '',
#   `num_procedures` VARCHAR(1) NOT NULL DEFAULT '',
#   `num_medications` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_outpatient` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_emergency` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_inpatient` VARCHAR(2) NOT NULL DEFAULT '',
#   `diag_1` VARCHAR(6) NOT NULL DEFAULT '',
#   `diag_2` VARCHAR(6) NOT NULL DEFAULT '',
#   `diag_3` VARCHAR(6) NOT NULL DEFAULT '',
#   `number_diagnoses` VARCHAR(2) NOT NULL DEFAULT '',
#   `examide` VARCHAR(2) NOT NULL DEFAULT '',
#   `citoglipton` VARCHAR(2) NOT NULL DEFAULT '',
#   `readmitted` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `gender_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_10` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_11` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_13` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_14` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_15` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_16` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_17` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_18` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_19` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_22` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_23` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_24` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_25` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_28` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_9` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_10` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_14` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_17` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_20` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_22` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_9` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `max_glu_serum_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `max_glu_serum_` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `A1Cresult_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `A1Cresult_` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Asian` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Caucasian` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Hispanic` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Other` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `chlorpropamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `chlorpropamide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolbutamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `miglitol_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `troglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolazamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `diabetesMed_0.5511333514483349` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#       `row_hash` BINARY(32)
#         GENERATED ALWAYS AS (UNHEX(SHA2(CONCAT_WS('|',COALESCE(`encounter_id`,''), COALESCE(`patient_nbr`,''), COALESCE(`age`,''), COALESCE(`time_in_hospital`,''), COALESCE(`num_lab_procedures`,''), COALESCE(`num_procedures`,''), COALESCE(`num_medications`,''), COALESCE(`number_outpatient`,''), COALESCE(`number_emergency`,''), COALESCE(`number_inpatient`,''), COALESCE(`diag_1`,''), COALESCE(`diag_2`,''), COALESCE(`diag_3`,''), COALESCE(`number_diagnoses`,''), COALESCE(`examide`,''), COALESCE(`citoglipton`,''), COALESCE(`readmitted`,''), COALESCE(`gender_1`,''), COALESCE(`admission_type_id_2`,''), COALESCE(`admission_type_id_3`,''), COALESCE(`admission_type_id_4`,''), COALESCE(`admission_type_id_5`,''), COALESCE(`admission_type_id_6`,''), COALESCE(`admission_type_id_7`,''), COALESCE(`admission_type_id_8`,''), COALESCE(`discharge_disposition_id_10`,''), COALESCE(`discharge_disposition_id_11`,''), COALESCE(`discharge_disposition_id_13`,''), COALESCE(`discharge_disposition_id_14`,''), COALESCE(`discharge_disposition_id_15`,''), COALESCE(`discharge_disposition_id_16`,''), COALESCE(`discharge_disposition_id_17`,''), COALESCE(`discharge_disposition_id_18`,''), COALESCE(`discharge_disposition_id_19`,''), COALESCE(`discharge_disposition_id_2`,''), COALESCE(`discharge_disposition_id_22`,''), COALESCE(`discharge_disposition_id_23`,''), COALESCE(`discharge_disposition_id_24`,''), COALESCE(`discharge_disposition_id_25`,''), COALESCE(`discharge_disposition_id_28`,''), COALESCE(`discharge_disposition_id_3`,''), COALESCE(`discharge_disposition_id_4`,''), COALESCE(`discharge_disposition_id_5`,''), COALESCE(`discharge_disposition_id_6`,''), COALESCE(`discharge_disposition_id_7`,''), COALESCE(`discharge_disposition_id_8`,''), COALESCE(`discharge_disposition_id_9`,''), COALESCE(`admission_source_id_10`,''), COALESCE(`admission_source_id_14`,''), COALESCE(`admission_source_id_17`,''), COALESCE(`admission_source_id_2`,''), COALESCE(`admission_source_id_20`,''), COALESCE(`admission_source_id_22`,''), COALESCE(`admission_source_id_3`,''), COALESCE(`admission_source_id_4`,''), COALESCE(`admission_source_id_5`,''), COALESCE(`admission_source_id_6`,''), COALESCE(`admission_source_id_7`,''), COALESCE(`admission_source_id_8`,''), COALESCE(`admission_source_id_9`,''), COALESCE(`max_glu_serum_1`,''), COALESCE(`max_glu_serum_`,''), COALESCE(`A1Cresult_1`,''), COALESCE(`A1Cresult_`,''), COALESCE(`race_Asian`,''), COALESCE(`race_Caucasian`,''), COALESCE(`race_Hispanic`,''), COALESCE(`race_Other`,''), COALESCE(`metformin_No`,''), COALESCE(`metformin_Steady`,''), COALESCE(`metformin_Up`,''), COALESCE(`repaglinide_No`,''), COALESCE(`repaglinide_Steady`,''), COALESCE(`repaglinide_Up`,''), COALESCE(`nateglinide_No`,''), COALESCE(`nateglinide_Steady`,''), COALESCE(`nateglinide_Up`,''), COALESCE(`chlorpropamide_Steady`,''), COALESCE(`chlorpropamide_Up`,''), COALESCE(`glimepiride_No`,''), COALESCE(`glimepiride_Steady`,''), COALESCE(`glimepiride_Up`,''), COALESCE(`glipizide_No`,''), COALESCE(`glipizide_Steady`,''), COALESCE(`glipizide_Up`,''), COALESCE(`glyburide_No`,''), COALESCE(`glyburide_Steady`,''), COALESCE(`glyburide_Up`,''), COALESCE(`tolbutamide_Steady`,''), COALESCE(`pioglitazone_No`,''), COALESCE(`pioglitazone_Steady`,''), COALESCE(`pioglitazone_Up`,''), COALESCE(`rosiglitazone_No`,''), COALESCE(`rosiglitazone_Steady`,''), COALESCE(`rosiglitazone_Up`,''), COALESCE(`acarbose_Steady`,''), COALESCE(`acarbose_Up`,''), COALESCE(`miglitol_Steady`,''), COALESCE(`troglitazone_Steady`,''), COALESCE(`tolazamide_Steady`,''), COALESCE(`insulin_No`,''), COALESCE(`insulin_Steady`,''), COALESCE(`insulin_Up`,''), COALESCE(`diabetesMed_0.5511333514483349`,'')), 256))) STORED,
#       UNIQUE KEY `uniq_row_hash` (`row_hash`),
#       PRIMARY KEY (`id`)
#     ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 ROW_FORMAT=DYNAMIC;
#
# 🔒 MySQL connection closed
# After create clean data  validate
# Inserting in index 0
# ✅ Inserted 5000 rows into clean_data_validate
# 🔒 MySQL connection closed
# Inserting in index 5000
# ✅ Inserted 5000 rows into clean_data_validate
# 🔒 MySQL connection closed
# Inserting in index 10000
# ✅ Inserted 5000 rows into clean_data_validate
# 🔒 MySQL connection closed
# Inserting in index 15000
# ✅ Inserted 2671 rows into clean_data_validate
# 🔒 MySQL connection closed
# 🔒 MySQL connection closed
# readmitted unique [0 1]
# readmitted unique readmitted
# 0    8661
# 1    1110
# Name: count, dtype: int64
# numerics ['readmitted', 'diabetesMed']
# numerics after removing readmitted ['diabetesMed']
# numerics ['readmitted', 'diabetesMed']
# numerics after removing readmitted ['diabetesMed']
# df_encoded readmitted 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: readmitted, dtype: int64
# create_table_with_types ddl
#     CREATE TABLE IF NOT EXISTS `clean_data_test` (
#       `id` BIGINT UNSIGNED NOT NULL AUTO_INCREMENT,
#       `encounter_id` VARCHAR(9) NOT NULL DEFAULT '',
#   `patient_nbr` VARCHAR(9) NOT NULL DEFAULT '',
#   `age` VARCHAR(2) NOT NULL DEFAULT '',
#   `time_in_hospital` VARCHAR(2) NOT NULL DEFAULT '',
#   `num_lab_procedures` VARCHAR(3) NOT NULL DEFAULT '',
#   `num_procedures` VARCHAR(1) NOT NULL DEFAULT '',
#   `num_medications` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_outpatient` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_emergency` VARCHAR(2) NOT NULL DEFAULT '',
#   `number_inpatient` VARCHAR(2) NOT NULL DEFAULT '',
#   `diag_1` VARCHAR(6) NOT NULL DEFAULT '',
#   `diag_2` VARCHAR(6) NOT NULL DEFAULT '',
#   `diag_3` VARCHAR(6) NOT NULL DEFAULT '',
#   `number_diagnoses` VARCHAR(2) NOT NULL DEFAULT '',
#   `examide` VARCHAR(2) NOT NULL DEFAULT '',
#   `citoglipton` VARCHAR(2) NOT NULL DEFAULT '',
#   `readmitted` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `gender_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_type_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_11` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_13` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_14` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_15` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_16` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_17` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_18` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_22` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_23` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_24` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_25` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_28` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_8` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `discharge_disposition_id_9` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_14` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_17` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_2` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_20` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_3` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_4` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_5` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_6` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_7` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `admission_source_id_9` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `max_glu_serum_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `max_glu_serum_` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `A1Cresult_1` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `A1Cresult_` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Asian` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Caucasian` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Hispanic` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `race_Other` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `metformin_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `repaglinide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `nateglinide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `chlorpropamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glimepiride_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glipizide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `glyburide_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolbutamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `pioglitazone_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `rosiglitazone_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `acarbose_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `miglitol_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `tolazamide_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_No` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_Steady` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `insulin_Up` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#   `diabetesMed_0.5424019360562977` TINYINT UNSIGNED NOT NULL DEFAULT 0,
#       `row_hash` BINARY(32)
#         GENERATED ALWAYS AS (UNHEX(SHA2(CONCAT_WS('|',COALESCE(`encounter_id`,''), COALESCE(`patient_nbr`,''), COALESCE(`age`,''), COALESCE(`time_in_hospital`,''), COALESCE(`num_lab_procedures`,''), COALESCE(`num_procedures`,''), COALESCE(`num_medications`,''), COALESCE(`number_outpatient`,''), COALESCE(`number_emergency`,''), COALESCE(`number_inpatient`,''), COALESCE(`diag_1`,''), COALESCE(`diag_2`,''), COALESCE(`diag_3`,''), COALESCE(`number_diagnoses`,''), COALESCE(`examide`,''), COALESCE(`citoglipton`,''), COALESCE(`readmitted`,''), COALESCE(`gender_1`,''), COALESCE(`admission_type_id_2`,''), COALESCE(`admission_type_id_3`,''), COALESCE(`admission_type_id_4`,''), COALESCE(`admission_type_id_5`,''), COALESCE(`admission_type_id_6`,''), COALESCE(`admission_type_id_7`,''), COALESCE(`admission_type_id_8`,''), COALESCE(`discharge_disposition_id_11`,''), COALESCE(`discharge_disposition_id_13`,''), COALESCE(`discharge_disposition_id_14`,''), COALESCE(`discharge_disposition_id_15`,''), COALESCE(`discharge_disposition_id_16`,''), COALESCE(`discharge_disposition_id_17`,''), COALESCE(`discharge_disposition_id_18`,''), COALESCE(`discharge_disposition_id_2`,''), COALESCE(`discharge_disposition_id_22`,''), COALESCE(`discharge_disposition_id_23`,''), COALESCE(`discharge_disposition_id_24`,''), COALESCE(`discharge_disposition_id_25`,''), COALESCE(`discharge_disposition_id_28`,''), COALESCE(`discharge_disposition_id_3`,''), COALESCE(`discharge_disposition_id_4`,''), COALESCE(`discharge_disposition_id_5`,''), COALESCE(`discharge_disposition_id_6`,''), COALESCE(`discharge_disposition_id_7`,''), COALESCE(`discharge_disposition_id_8`,''), COALESCE(`discharge_disposition_id_9`,''), COALESCE(`admission_source_id_14`,''), COALESCE(`admission_source_id_17`,''), COALESCE(`admission_source_id_2`,''), COALESCE(`admission_source_id_20`,''), COALESCE(`admission_source_id_3`,''), COALESCE(`admission_source_id_4`,''), COALESCE(`admission_source_id_5`,''), COALESCE(`admission_source_id_6`,''), COALESCE(`admission_source_id_7`,''), COALESCE(`admission_source_id_9`,''), COALESCE(`max_glu_serum_1`,''), COALESCE(`max_glu_serum_`,''), COALESCE(`A1Cresult_1`,''), COALESCE(`A1Cresult_`,''), COALESCE(`race_Asian`,''), COALESCE(`race_Caucasian`,''), COALESCE(`race_Hispanic`,''), COALESCE(`race_Other`,''), COALESCE(`metformin_No`,''), COALESCE(`metformin_Steady`,''), COALESCE(`metformin_Up`,''), COALESCE(`repaglinide_No`,''), COALESCE(`repaglinide_Steady`,''), COALESCE(`repaglinide_Up`,''), COALESCE(`nateglinide_No`,''), COALESCE(`nateglinide_Steady`,''), COALESCE(`nateglinide_Up`,''), COALESCE(`chlorpropamide_Steady`,''), COALESCE(`glimepiride_No`,''), COALESCE(`glimepiride_Steady`,''), COALESCE(`glimepiride_Up`,''), COALESCE(`glipizide_No`,''), COALESCE(`glipizide_Steady`,''), COALESCE(`glipizide_Up`,''), COALESCE(`glyburide_No`,''), COALESCE(`glyburide_Steady`,''), COALESCE(`glyburide_Up`,''), COALESCE(`tolbutamide_Steady`,''), COALESCE(`pioglitazone_No`,''), COALESCE(`pioglitazone_Steady`,''), COALESCE(`pioglitazone_Up`,''), COALESCE(`rosiglitazone_No`,''), COALESCE(`rosiglitazone_Steady`,''), COALESCE(`rosiglitazone_Up`,''), COALESCE(`acarbose_Steady`,''), COALESCE(`acarbose_Up`,''), COALESCE(`miglitol_Steady`,''), COALESCE(`tolazamide_Steady`,''), COALESCE(`insulin_No`,''), COALESCE(`insulin_Steady`,''), COALESCE(`insulin_Up`,''), COALESCE(`diabetesMed_0.5424019360562977`,'')), 256))) STORED,
#       UNIQUE KEY `uniq_row_hash` (`row_hash`),
#       PRIMARY KEY (`id`)
#     ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 ROW_FORMAT=DYNAMIC;
#
# 🔒 MySQL connection closed
# After create clean data  test
# Inserting in index 0
# ✅ Inserted 5000 rows into clean_data_test
# 🔒 MySQL connection closed
# Inserting in index 5000
# ✅ Inserted 4260 rows into clean_data_test
# 🔒 MySQL connection closed
# clean data saved
